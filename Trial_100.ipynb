# %%
# %pip install optuna
# %pip install catboost
# %pip install shap
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (4.2.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (1.14.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna) (2.0.38)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (1.3.9)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.11/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.11/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Requirement already satisfied: catboost in /usr/local/lib/python3.11/dist-packages (1.2.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (9.0.0)
# Requirement already satisfied: shap in /usr/local/lib/python3.11/dist-packages (0.46.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from shap) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from shap) (1.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from shap) (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.11/dist-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.11/dist-packages (from shap) (24.2)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.11/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in /usr/local/lib/python3.11/dist-packages (from shap) (0.61.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from shap) (3.1.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba->shap) (0.44.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2025.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from imblearn.combine import SMOTEENN
import lightgbm as lgb
from catboost import CatBoostClassifier
from sklearn.impute import SimpleImputer
import shap
import matplotlib.pyplot as plt
import optuna

from sklearn.model_selection import StratifiedKFold

# %%
# 1. 데이터 로드
train = pd.read_csv('train.csv').drop(columns=['ID'])
test = pd.read_csv('test.csv').drop(columns=['ID'])

# train 데이터 복사하여 사용
train_df = train.copy()
test_df = test.copy()


X = train.drop(columns=['임신 성공 여부'], errors='ignore')
y = train['임신 성공 여부']

# %%
# 2. 유니크 값이 1개인 컬럼 삭제
drop_cols = ['불임 원인 - 여성 요인', '난자 채취 경과일']
X.drop(columns=drop_cols, inplace=True, errors='ignore')
test_df.drop(columns=drop_cols, inplace=True, errors='ignore')

# 3. '배란 자극 여부'에 따른 '배란 유도 유형' 수정
if '배란 유도 유형' in X.columns:
    X.loc[(X['배란 자극 여부'] == 0) & (X['배란 유도 유형'] == '알 수 없음'), '배란 유도 유형'] = '시행 없음'
    X.loc[(X['배란 자극 여부'] == 1) & (X['배란 유도 유형'] == '알 수 없음'), '배란 유도 유형'] = '기록되지 않은 시행'

if '배란 유도 유형' in test_df.columns:
    test_df.loc[(test_df['배란 자극 여부'] == 0) & (test_df['배란 유도 유형'] == '알 수 없음'), '배란 유도 유형'] = '시행 없음'
    test_df.loc[(test_df['배란 자극 여부'] == 1) & (test_df['배란 유도 유형'] == '알 수 없음'), '배란 유도 유형'] = '기록되지 않은 시행'

# 4. 숫자형 컬럼 값 정수 변환
cols_to_slice = ['총 시술 횟수', '클리닉 내 총 시술 횟수', 'IVF 시술 횟수', 'DI 시술 횟수',
                 '총 임신 횟수', 'IVF 임신 횟수', 'DI 임신 횟수', '총 출산 횟수', 'IVF 출산 횟수', 'DI 출산 횟수']
for col in cols_to_slice:
    X[col] = X[col].astype(str).str.extract(r'(\d+)').astype(float).fillna(0).astype(int)
    test_df[col] = test_df[col].astype(str).str.extract(r'(\d+)').astype(float).fillna(0).astype(int)

# 5. 특정 NaN 값 채우기 (가장 많이 등장한 값 적용)
columns_to_fill_most_frequent = ['특정 시술 유형', '배아 생성 주요 이유']
imputer_cat = SimpleImputer(strategy="most_frequent")
X[columns_to_fill_most_frequent] = imputer_cat.fit_transform(X[columns_to_fill_most_frequent])
test_df[columns_to_fill_most_frequent] = imputer_cat.transform(test_df[columns_to_fill_most_frequent])

# 6. 특정 값이 NaN이면 0으로 변환
columns_to_fill_zero = ['단일 배아 이식 여부', '착상 전 유전 검사 사용 여부', '착상 전 유전 진단 사용 여부', '이식된 배아 수']
for col in columns_to_fill_zero:
    X[col] = X[col].fillna(0)
    test_df[col] = test_df[col].fillna(0)

# %%
# 2. 범주형 변수 및 수치형 변수 구분
categorical_columns = X.select_dtypes(include=['object', 'category']).columns.tolist()
numeric_columns = X.select_dtypes(include=['int64', 'float64']).columns.tolist()

# %%
label_encoders = {}
for col in categorical_columns:
    le = LabelEncoder()
    X[col] = X[col].fillna('Unknown').astype(str)
    test[col] = test[col].fillna('Unknown').astype(str)
    X[col] = le.fit_transform(X[col])
    label_encoders[col] = le
    test[col] = test[col].apply(lambda x: x if x in le.classes_ else 'Unknown')
    if 'Unknown' not in le.classes_:
        le.classes_ = np.append(le.classes_, 'Unknown')
    test[col] = le.transform(test[col])

# %%
# 5. 수치형 변수 결측치 처리 (평균값 대체) - 존재하는 변수만 처리
for col in numeric_columns:
    if col in X.columns:
        mean_value = X[col].mean()
        X[col] = X[col].fillna(mean_value)
        if col in test.columns:
            test[col] = test[col].fillna(mean_value)

# %%
def create_features(df):
    """
    모델 성능 향상을 위한 주요 파생 변수 생성
    """
    # 시술 관련 파생 변수
    df["시술 횟수 대비 배아 생성률"] = df["총 생성 배아 수"] / df["총 시술 횟수"].astype(float)
    df["시술 횟수 대비 임신 성공률"] = df["총 임신 횟수"] / df["총 시술 횟수"].astype(float)
    df["시술 횟수 대비 출산 성공률"] = df["총 출산 횟수"] / df["총 시술 횟수"].astype(float)
    df["배아 이식 후 성공률"] = df["총 출산 횟수"] / df["이식된 배아 수"]

    # 배아 및 난자 관련 파생 변수
    df["난자 채취 대비 배아 생성률"] = df["총 생성 배아 수"] / df["수집된 신선 난자 수"]
    df["미세주입 대비 배아 생성률"] = df["미세주입에서 생성된 배아 수"] / df["미세주입된 난자 수"]
    df["배아 해동 후 이식률"] = df["배아 이식 경과일"] / df["배아 해동 경과일"]

    # 불임 원인 개수
    infertility_cols = ["남성 주 불임 원인", "여성 주 불임 원인", "불명확 불임 원인", "불임 원인 - 난관 질환",
                        "불임 원인 - 남성 요인", "불임 원인 - 배란 장애", "불임 원인 - 여성 요인", "불임 원인 - 자궁경부 문제",
                        "불임 원인 - 자궁내막증", "불임 원인 - 정자 농도", "불임 원인 - 정자 면역학적 요인", "불임 원인 - 정자 운동성",
                        "불임 원인 - 정자 형태"]
    df["불임 원인 개수"] = df[infertility_cols].sum(axis=1)

    # 시술 당시 나이대 그룹
    df["시술 당시 나이"] = df["시술 당시 나이"].astype(int)
    df["나이대 그룹"] = pd.cut(df["시술 당시 나이"], bins=[20, 30, 40, 50], labels=["20대", "30대", "40대 이상"])

    # 결측치 처리
    df = df.fillna(-1)

    return df

# %%
from sklearn.model_selection import train_test_split

# 파생변수 생성 후 적용된 데이터에서 타겟 변수 분리
X_train_final = train_df.drop(columns=['임신 성공 여부'])
y_train_final = train_df['임신 성공 여부']

# 데이터 분할 (Stratify 옵션 적용)
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_final, y_train_final, test_size=0.2, random_state=42, stratify=y_train_final
)

print(f"Train 데이터 크기: {X_train.shape}, Validation 데이터 크기: {X_valid.shape}")
# Out:
# Train 데이터 크기: (205080, 67), Validation 데이터 크기: (51271, 67)

# %%
# 범주형 변수 변환 (Label Encoding) & 새로운 값 처리
categorical_columns = X_train.select_dtypes(include=['object']).columns.tolist()
label_encoders = {}

for col in categorical_columns:
    le = LabelEncoder()
    X_train[col] = X_train[col].fillna('Unknown').astype(str)
    X_valid[col] = X_valid[col].fillna('Unknown').astype(str)

    X_train[col] = le.fit_transform(X_train[col])  # 학습 데이터 변환
    label_encoders[col] = le  # 인코더 저장

    # 검증 데이터 변환 (새로운 값이 나오면 'Unknown'으로 처리)
    X_valid[col] = X_valid[col].apply(lambda x: x if x in le.classes_ else 'Unknown')
    if 'Unknown' not in le.classes_:
        le.classes_ = np.append(le.classes_, 'Unknown')
    X_valid[col] = le.transform(X_valid[col])

# Optuna + CatBoost 튜닝 실행
def objective(trial):
    params = {
        'iterations': trial.suggest_int('iterations', 1000, 3000),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2),
        'depth': trial.suggest_int('depth', 4, 12),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1, 20),
        'border_count': trial.suggest_int('border_count', 32, 255),
        'bagging_temperature': trial.suggest_float('bagging_temperature', 0, 1),
        'random_strength': trial.suggest_float('random_strength', 0, 10),
        'scale_pos_weight': len(y_train) / sum(y_train),  # 클래스 불균형 자동 조정
        'eval_metric': 'AUC',
        'random_seed': 42,
        'verbose': 0
    }

    # K-Fold Cross Validation
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    auc_scores = []

    for train_idx, valid_idx in skf.split(X_train, y_train):
        X_tr, X_val = X_train.iloc[train_idx], X_train.iloc[valid_idx]
        y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[valid_idx]

        model = CatBoostClassifier(**params)
        model.fit(X_tr, y_tr, eval_set=(X_val, y_val), early_stopping_rounds=100, verbose=0)

        preds = model.predict_proba(X_val)[:, 1]
        auc_scores.append(roc_auc_score(y_val, preds))

    return np.mean(auc_scores)

# %%
# Optuna 실행
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

# 최적의 파라미터 출력
print("Best parameters:", study.best_params)  #Trial 33번이 젤 높음
# Out:
# [I 2025-02-24 19:50:49,395] A new study created in memory with name: no-name-09939a51-ecb8-46a0-b5f0-6e78104cd936
# [I 2025-02-24 19:52:58,913] Trial 0 finished with value: 0.7395721678969408 and parameters: {'iterations': 1073, 'learning_rate': 0.10318164117101428, 'depth': 5, 'l2_leaf_reg': 12.72501394354848, 'border_count': 147, 'bagging_temperature': 0.7777738685150848, 'random_strength': 7.914935522421982}. Best is trial 0 with value: 0.7395721678969408.
# [I 2025-02-24 19:55:27,704] Trial 1 finished with value: 0.7394767086529532 and parameters: {'iterations': 1929, 'learning_rate': 0.06616376150042003, 'depth': 8, 'l2_leaf_reg': 3.3512217626233247, 'border_count': 184, 'bagging_temperature': 0.4505280569295319, 'random_strength': 8.594522039789808}. Best is trial 0 with value: 0.7395721678969408.
# [I 2025-02-24 19:57:42,619] Trial 2 finished with value: 0.7381356639246041 and parameters: {'iterations': 2109, 'learning_rate': 0.17564736064627168, 'depth': 10, 'l2_leaf_reg': 18.493890951716633, 'border_count': 248, 'bagging_temperature': 0.5983883299379678, 'random_strength': 0.1269427759771491}. Best is trial 0 with value: 0.7395721678969408.
# [I 2025-02-24 20:00:35,478] Trial 3 finished with value: 0.7381853615988412 and parameters: {'iterations': 2787, 'learning_rate': 0.19683567278002384, 'depth': 10, 'l2_leaf_reg': 11.033099383258065, 'border_count': 237, 'bagging_temperature': 0.9621369063632439, 'random_strength': 9.625738553603155}. Best is trial 0 with value: 0.7395721678969408.
# [I 2025-02-24 20:01:48,720] Trial 4 finished with value: 0.7398208914006122 and parameters: {'iterations': 1612, 'learning_rate': 0.15321358505884924, 'depth': 4, 'l2_leaf_reg': 4.455221425893296, 'border_count': 86, 'bagging_temperature': 0.15271959288214942, 'random_strength': 0.32648803851174746}. Best is trial 4 with value: 0.7398208914006122.
# [I 2025-02-24 20:03:16,560] Trial 5 finished with value: 0.7398871975853675 and parameters: {'iterations': 1791, 'learning_rate': 0.10971387030230474, 'depth': 7, 'l2_leaf_reg': 6.355747428373584, 'border_count': 61, 'bagging_temperature': 0.5708868991900353, 'random_strength': 0.5639459956474846}. Best is trial 5 with value: 0.7398871975853675.
# [I 2025-02-24 20:05:39,938] Trial 6 finished with value: 0.7384461892752181 and parameters: {'iterations': 1688, 'learning_rate': 0.16248800881030553, 'depth': 10, 'l2_leaf_reg': 13.224174540607345, 'border_count': 137, 'bagging_temperature': 0.4132657782531701, 'random_strength': 0.3692879265998683}. Best is trial 5 with value: 0.7398871975853675.
# [I 2025-02-24 20:07:02,913] Trial 7 finished with value: 0.7394705584779937 and parameters: {'iterations': 2943, 'learning_rate': 0.16175319344409203, 'depth': 8, 'l2_leaf_reg': 10.513742246728413, 'border_count': 181, 'bagging_temperature': 0.226156089840723, 'random_strength': 2.7893939577739335}. Best is trial 5 with value: 0.7398871975853675.
# [I 2025-02-24 20:09:41,076] Trial 8 finished with value: 0.7398812165779127 and parameters: {'iterations': 2891, 'learning_rate': 0.05245009223269346, 'depth': 8, 'l2_leaf_reg': 18.895089971608716, 'border_count': 183, 'bagging_temperature': 0.0074357644721615435, 'random_strength': 0.7014934594188804}. Best is trial 5 with value: 0.7398871975853675.
# [I 2025-02-24 20:14:17,281] Trial 9 finished with value: 0.73966789558972 and parameters: {'iterations': 1212, 'learning_rate': 0.03279244476586887, 'depth': 9, 'l2_leaf_reg': 12.838564369363809, 'border_count': 238, 'bagging_temperature': 0.09848265928524691, 'random_strength': 6.118691124151555}. Best is trial 5 with value: 0.7398871975853675.
# [I 2025-02-24 20:16:03,148] Trial 10 finished with value: 0.7394381579953386 and parameters: {'iterations': 2394, 'learning_rate': 0.11210707717987005, 'depth': 6, 'l2_leaf_reg': 6.455045176558342, 'border_count': 41, 'bagging_temperature': 0.6787860402433165, 'random_strength': 4.142900333947601}. Best is trial 5 with value: 0.7398871975853675.
# [I 2025-02-24 20:33:33,619] Trial 11 finished with value: 0.7394655773853691 and parameters: {'iterations': 2458, 'learning_rate': 0.020326603295929377, 'depth': 12, 'l2_leaf_reg': 19.982885790687074, 'border_count': 43, 'bagging_temperature': 0.33684470756509466, 'random_strength': 2.4277818185457436}. Best is trial 5 with value: 0.7398871975853675.
# [I 2025-02-24 20:35:41,643] Trial 12 finished with value: 0.7399253450650287 and parameters: {'iterations': 1496, 'learning_rate': 0.07576333761399913, 'depth': 7, 'l2_leaf_reg': 6.899754984918958, 'border_count': 92, 'bagging_temperature': 0.8275282504653823, 'random_strength': 1.9756891853099152}. Best is trial 12 with value: 0.7399253450650287.
# [I 2025-02-24 20:37:30,853] Trial 13 finished with value: 0.7396143095860255 and parameters: {'iterations': 1404, 'learning_rate': 0.1013564191751143, 'depth': 6, 'l2_leaf_reg': 7.140451208249272, 'border_count': 89, 'bagging_temperature': 0.9094569433649863, 'random_strength': 2.4033270738522248}. Best is trial 12 with value: 0.7399253450650287.
# [I 2025-02-24 20:39:41,745] Trial 14 finished with value: 0.7394460096158161 and parameters: {'iterations': 1806, 'learning_rate': 0.07983205467243941, 'depth': 6, 'l2_leaf_reg': 1.3658322107641512, 'border_count': 85, 'bagging_temperature': 0.7650995613668787, 'random_strength': 4.407177443937299}. Best is trial 12 with value: 0.7399253450650287.
# [I 2025-02-24 20:41:01,722] Trial 15 finished with value: 0.7397194143861376 and parameters: {'iterations': 1382, 'learning_rate': 0.12278788538698102, 'depth': 7, 'l2_leaf_reg': 7.6315530495698916, 'border_count': 114, 'bagging_temperature': 0.5805528468379143, 'random_strength': 1.7053040167293665}. Best is trial 12 with value: 0.7399253450650287.
# [I 2025-02-24 20:42:53,775] Trial 16 finished with value: 0.7397520606246641 and parameters: {'iterations': 2137, 'learning_rate': 0.12779923242634436, 'depth': 4, 'l2_leaf_reg': 5.139320321307811, 'border_count': 64, 'bagging_temperature': 0.826217881928029, 'random_strength': 5.974531681251932}. Best is trial 12 with value: 0.7399253450650287.
# [I 2025-02-24 20:44:49,782] Trial 17 finished with value: 0.7399033064878304 and parameters: {'iterations': 1468, 'learning_rate': 0.08320164840271227, 'depth': 7, 'l2_leaf_reg': 8.822635477945916, 'border_count': 113, 'bagging_temperature': 0.637241299079732, 'random_strength': 1.5641643986686273}. Best is trial 12 with value: 0.7399253450650287.
# [I 2025-02-24 20:51:25,113] Trial 18 finished with value: 0.7390447795848895 and parameters: {'iterations': 1448, 'learning_rate': 0.07701698708030001, 'depth': 12, 'l2_leaf_reg': 9.11360202856486, 'border_count': 125, 'bagging_temperature': 0.6884117803352803, 'random_strength': 3.8136233683615606}. Best is trial 12 with value: 0.7399253450650287.
# [I 2025-02-24 20:54:34,191] Trial 19 finished with value: 0.7400079897248325 and parameters: {'iterations': 1080, 'learning_rate': 0.04408755447754997, 'depth': 7, 'l2_leaf_reg': 15.43011110286706, 'border_count': 159, 'bagging_temperature': 0.8762875350037902, 'random_strength': 1.4070587215131365}. Best is trial 19 with value: 0.7400079897248325.
# [I 2025-02-24 20:58:20,004] Trial 20 finished with value: 0.7399054124966673 and parameters: {'iterations': 1086, 'learning_rate': 0.04322074651421655, 'depth': 5, 'l2_leaf_reg': 16.164186210519112, 'border_count': 157, 'bagging_temperature': 0.9905874137544264, 'random_strength': 3.4679272987627963}. Best is trial 19 with value: 0.7400079897248325.
# [I 2025-02-24 21:01:57,014] Trial 21 finished with value: 0.7399055467533845 and parameters: {'iterations': 1034, 'learning_rate': 0.045888522169469134, 'depth': 5, 'l2_leaf_reg': 15.91946111913807, 'border_count': 165, 'bagging_temperature': 0.9907083324568933, 'random_strength': 3.2619813016460433}. Best is trial 19 with value: 0.7400079897248325.
# [I 2025-02-24 21:06:53,628] Trial 22 finished with value: 0.73680893997341 and parameters: {'iterations': 1015, 'learning_rate': 0.011642572914914558, 'depth': 5, 'l2_leaf_reg': 16.312938131750414, 'border_count': 211, 'bagging_temperature': 0.8646541701409187, 'random_strength': 5.2850616160029205}. Best is trial 19 with value: 0.7400079897248325.
# [I 2025-02-24 21:10:00,245] Trial 23 finished with value: 0.7398474324784513 and parameters: {'iterations': 1229, 'learning_rate': 0.04916701290176678, 'depth': 7, 'l2_leaf_reg': 15.336496484249196, 'border_count': 165, 'bagging_temperature': 0.9124023437982323, 'random_strength': 1.997232008144302}. Best is trial 19 with value: 0.7400079897248325.
# [I 2025-02-24 21:12:40,340] Trial 24 finished with value: 0.7395902612541593 and parameters: {'iterations': 1212, 'learning_rate': 0.06595911501531115, 'depth': 9, 'l2_leaf_reg': 15.372219742139746, 'border_count': 198, 'bagging_temperature': 0.9980832351157877, 'random_strength': 3.076724244980194}. Best is trial 19 with value: 0.7400079897248325.
# [I 2025-02-24 21:16:53,837] Trial 25 finished with value: 0.7400053805193791 and parameters: {'iterations': 1209, 'learning_rate': 0.031475822195827875, 'depth': 6, 'l2_leaf_reg': 17.473372330976694, 'border_count': 136, 'bagging_temperature': 0.7594145815888699, 'random_strength': 1.2393600511672567}. Best is trial 19 with value: 0.7400079897248325.
# [I 2025-02-24 21:22:28,783] Trial 26 finished with value: 0.7400013666121208 and parameters: {'iterations': 1576, 'learning_rate': 0.02263608197760156, 'depth': 6, 'l2_leaf_reg': 13.57190182144659, 'border_count': 103, 'bagging_temperature': 0.7505938630538996, 'random_strength': 1.18754936829165}. Best is trial 19 with value: 0.7400079897248325.
# [I 2025-02-24 21:26:50,169] Trial 27 finished with value: 0.739988233256413 and parameters: {'iterations': 1291, 'learning_rate': 0.03036685439288682, 'depth': 6, 'l2_leaf_reg': 17.53530520569379, 'border_count': 132, 'bagging_temperature': 0.7436051318892872, 'random_strength': 1.3814314178121367}. Best is trial 19 with value: 0.7400079897248325.
# [I 2025-02-24 21:35:30,944] Trial 28 finished with value: 0.7399782507468864 and parameters: {'iterations': 1647, 'learning_rate': 0.01166794354391878, 'depth': 6, 'l2_leaf_reg': 13.222097171780208, 'border_count': 107, 'bagging_temperature': 0.7126298574015801, 'random_strength': 0.9886577324122197}. Best is trial 19 with value: 0.7400079897248325.
# [I 2025-02-24 21:40:45,647] Trial 29 finished with value: 0.7396924668873877 and parameters: {'iterations': 1159, 'learning_rate': 0.027657888126836543, 'depth': 4, 'l2_leaf_reg': 14.377507188009385, 'border_count': 144, 'bagging_temperature': 0.7961362783794742, 'random_strength': 7.081069844967584}. Best is trial 19 with value: 0.7400079897248325.
# [I 2025-02-24 21:43:16,956] Trial 30 finished with value: 0.7398977860827477 and parameters: {'iterations': 1319, 'learning_rate': 0.06043006976004621, 'depth': 5, 'l2_leaf_reg': 11.334239145561448, 'border_count': 158, 'bagging_temperature': 0.5274106810471458, 'random_strength': 1.1445407503272989}. Best is trial 19 with value: 0.7400079897248325.
# [I 2025-02-24 21:47:24,067] Trial 31 finished with value: 0.7399969518113235 and parameters: {'iterations': 1299, 'learning_rate': 0.030952456026817905, 'depth': 6, 'l2_leaf_reg': 17.56893598462133, 'border_count': 129, 'bagging_temperature': 0.7595244561231838, 'random_strength': 1.2497512577909402}. Best is trial 19 with value: 0.7400079897248325.
# [I 2025-02-24 21:51:35,921] Trial 32 finished with value: 0.7399281624775865 and parameters: {'iterations': 1558, 'learning_rate': 0.03755936127939946, 'depth': 6, 'l2_leaf_reg': 17.168409632120195, 'border_count': 121, 'bagging_temperature': 0.8870949560950302, 'random_strength': 2.3734261988217265}. Best is trial 19 with value: 0.7400079897248325.
# [I 2025-02-24 21:57:27,115] Trial 33 finished with value: 0.7400806190663121 and parameters: {'iterations': 1128, 'learning_rate': 0.01974308829097581, 'depth': 7, 'l2_leaf_reg': 14.254967637674017, 'border_count': 146, 'bagging_temperature': 0.6490942636012634, 'random_strength': 1.157639810266331}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 22:03:27,087] Trial 34 finished with value: 0.7398449537255063 and parameters: {'iterations': 1119, 'learning_rate': 0.015591610150817975, 'depth': 8, 'l2_leaf_reg': 14.316524606927263, 'border_count': 101, 'bagging_temperature': 0.6476281976451413, 'random_strength': 0.10767979333745914}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 22:10:03,871] Trial 35 finished with value: 0.7396576995682645 and parameters: {'iterations': 1915, 'learning_rate': 0.022346900757650223, 'depth': 9, 'l2_leaf_reg': 14.108762501808398, 'border_count': 144, 'bagging_temperature': 0.47900646486551524, 'random_strength': 8.792423704703502}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 22:12:07,949] Trial 36 finished with value: 0.7398583987595664 and parameters: {'iterations': 1007, 'learning_rate': 0.05860304021131971, 'depth': 7, 'l2_leaf_reg': 11.683870546637344, 'border_count': 199, 'bagging_temperature': 0.6166656909321627, 'random_strength': 0.005724299292399593}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 22:15:14,192] Trial 37 finished with value: 0.7397521724907092 and parameters: {'iterations': 1155, 'learning_rate': 0.03787639822322149, 'depth': 8, 'l2_leaf_reg': 12.017609700321525, 'border_count': 158, 'bagging_temperature': 0.5389937037335315, 'random_strength': 0.7121317327539624}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 22:21:51,329] Trial 38 finished with value: 0.7386699725672616 and parameters: {'iterations': 1341, 'learning_rate': 0.010670058343879426, 'depth': 5, 'l2_leaf_reg': 18.77551999919779, 'border_count': 173, 'bagging_temperature': 0.42665121089292535, 'random_strength': 2.8281654960302207}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 22:25:07,932] Trial 39 finished with value: 0.7397241789547999 and parameters: {'iterations': 1722, 'learning_rate': 0.05305884303086945, 'depth': 7, 'l2_leaf_reg': 14.560561925814277, 'border_count': 67, 'bagging_temperature': 0.7214479246213619, 'random_strength': 9.968094275717995}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 22:26:41,985] Trial 40 finished with value: 0.7396280206438934 and parameters: {'iterations': 2117, 'learning_rate': 0.09544507759558096, 'depth': 8, 'l2_leaf_reg': 16.643678322701565, 'border_count': 148, 'bagging_temperature': 0.8542645334824296, 'random_strength': 0.7311427701394825}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 22:31:45,402] Trial 41 finished with value: 0.7400023070491273 and parameters: {'iterations': 1554, 'learning_rate': 0.026242050356720618, 'depth': 6, 'l2_leaf_reg': 17.915024500683103, 'border_count': 131, 'bagging_temperature': 0.7834103404949284, 'random_strength': 1.3452283070368238}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 22:37:59,794] Trial 42 finished with value: 0.7400418694936517 and parameters: {'iterations': 1555, 'learning_rate': 0.021467784939728472, 'depth': 7, 'l2_leaf_reg': 19.669511437803255, 'border_count': 136, 'bagging_temperature': 0.79855153862436, 'random_strength': 1.9075259059910383}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 22:41:30,135] Trial 43 finished with value: 0.7399275593788079 and parameters: {'iterations': 1994, 'learning_rate': 0.03959790847265274, 'depth': 7, 'l2_leaf_reg': 19.6812978251921, 'border_count': 138, 'bagging_temperature': 0.922048317508932, 'random_strength': 1.872452833769867}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 22:47:10,459] Trial 44 finished with value: 0.7399094788646267 and parameters: {'iterations': 1806, 'learning_rate': 0.023782784682742062, 'depth': 8, 'l2_leaf_reg': 18.51636874906067, 'border_count': 147, 'bagging_temperature': 0.8219377367033387, 'random_strength': 2.324472714917655}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 22:48:13,697] Trial 45 finished with value: 0.739388155838746 and parameters: {'iterations': 2260, 'learning_rate': 0.18508410791770954, 'depth': 7, 'l2_leaf_reg': 17.99874264355364, 'border_count': 175, 'bagging_temperature': 0.6678435168698835, 'random_strength': 0.44154166885752}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 22:58:01,445] Trial 46 finished with value: 0.7394629190782072 and parameters: {'iterations': 2588, 'learning_rate': 0.03347567192294821, 'depth': 11, 'l2_leaf_reg': 19.534478407984796, 'border_count': 121, 'bagging_temperature': 0.8059536821626466, 'random_strength': 2.6913443818419345}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 22:59:28,409] Trial 47 finished with value: 0.7395532150427545 and parameters: {'iterations': 1521, 'learning_rate': 0.1425827891666031, 'depth': 6, 'l2_leaf_reg': 18.329069906662, 'border_count': 194, 'bagging_temperature': 0.9510858929260022, 'random_strength': 1.889520856596721}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 23:05:39,691] Trial 48 finished with value: 0.7399595978980803 and parameters: {'iterations': 1250, 'learning_rate': 0.018540825663553216, 'depth': 8, 'l2_leaf_reg': 17.042828591422584, 'border_count': 134, 'bagging_temperature': 0.37552161442570847, 'random_strength': 0.945959047533685}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 23:08:22,631] Trial 49 finished with value: 0.7395033170884684 and parameters: {'iterations': 1121, 'learning_rate': 0.06686634687722379, 'depth': 9, 'l2_leaf_reg': 15.149009914859958, 'border_count': 155, 'bagging_temperature': 0.7858238044213935, 'random_strength': 4.7261456951499525}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 23:11:38,804] Trial 50 finished with value: 0.7399770946728119 and parameters: {'iterations': 1410, 'learning_rate': 0.04501044012287784, 'depth': 7, 'l2_leaf_reg': 19.05115990019005, 'border_count': 216, 'bagging_temperature': 0.7019386726117038, 'random_strength': 1.615779294759622}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 23:15:54,694] Trial 51 finished with value: 0.7399149621318687 and parameters: {'iterations': 1578, 'learning_rate': 0.026315613798515502, 'depth': 6, 'l2_leaf_reg': 13.374806716103393, 'border_count': 99, 'bagging_temperature': 0.7470760002440773, 'random_strength': 0.43988217850902755}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 23:22:07,294] Trial 52 finished with value: 0.7399864339265241 and parameters: {'iterations': 1660, 'learning_rate': 0.020019112294631797, 'depth': 6, 'l2_leaf_reg': 10.17713459189066, 'border_count': 114, 'bagging_temperature': 0.8518704231180569, 'random_strength': 1.3677258563882833}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 23:26:17,455] Trial 53 finished with value: 0.7399480088073972 and parameters: {'iterations': 1918, 'learning_rate': 0.03232230114510635, 'depth': 7, 'l2_leaf_reg': 17.810353061897843, 'border_count': 138, 'bagging_temperature': 0.5951803568579246, 'random_strength': 2.1368523608245265}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 23:28:42,607] Trial 54 finished with value: 0.7399218551926386 and parameters: {'iterations': 1779, 'learning_rate': 0.053448229746099224, 'depth': 6, 'l2_leaf_reg': 15.811923309500338, 'border_count': 81, 'bagging_temperature': 0.7674385608581181, 'random_strength': 0.9696763175830447}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 23:35:11,969] Trial 55 finished with value: 0.7399792978983395 and parameters: {'iterations': 1469, 'learning_rate': 0.020940832525780648, 'depth': 5, 'l2_leaf_reg': 12.26382739370195, 'border_count': 123, 'bagging_temperature': 0.8780146591695265, 'random_strength': 1.6881530590950762}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 23:39:54,517] Trial 56 finished with value: 0.7398715144900485 and parameters: {'iterations': 1184, 'learning_rate': 0.03886068000607747, 'depth': 5, 'l2_leaf_reg': 16.76470821311708, 'border_count': 166, 'bagging_temperature': 0.9414853378742529, 'random_strength': 3.908003049984732}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 23:47:27,139] Trial 57 finished with value: 0.7399703690135389 and parameters: {'iterations': 1355, 'learning_rate': 0.015423810723450261, 'depth': 7, 'l2_leaf_reg': 13.658005589495165, 'border_count': 106, 'bagging_temperature': 0.648001958772134, 'random_strength': 2.6988876753656315}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 23:49:06,622] Trial 58 finished with value: 0.73977376895905 and parameters: {'iterations': 1072, 'learning_rate': 0.09032214043301438, 'depth': 6, 'l2_leaf_reg': 15.149572039840638, 'border_count': 76, 'bagging_temperature': 0.7326420950135144, 'random_strength': 0.44617314241602246}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 23:53:44,951] Trial 59 finished with value: 0.7400422055579724 and parameters: {'iterations': 1740, 'learning_rate': 0.025937911882239106, 'depth': 7, 'l2_leaf_reg': 12.663775669211201, 'border_count': 92, 'bagging_temperature': 0.8318316981838061, 'random_strength': 1.376629209551833}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-24 23:57:02,913] Trial 60 finished with value: 0.7397673945328432 and parameters: {'iterations': 1731, 'learning_rate': 0.04360256814641372, 'depth': 8, 'l2_leaf_reg': 12.473768737713238, 'border_count': 50, 'bagging_temperature': 0.2998545045895931, 'random_strength': 3.2078286392944326}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 00:01:42,828] Trial 61 finished with value: 0.7399981407553875 and parameters: {'iterations': 1641, 'learning_rate': 0.025635544481816763, 'depth': 7, 'l2_leaf_reg': 10.655835819978254, 'border_count': 96, 'bagging_temperature': 0.8417194038966173, 'random_strength': 1.539762439837049}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 00:05:33,194] Trial 62 finished with value: 0.7400448293215487 and parameters: {'iterations': 1833, 'learning_rate': 0.032793048378332336, 'depth': 7, 'l2_leaf_reg': 19.219748886980064, 'border_count': 151, 'bagging_temperature': 0.794020872981005, 'random_strength': 1.1637517912655284}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 00:08:48,319] Trial 63 finished with value: 0.7399258276235006 and parameters: {'iterations': 1856, 'learning_rate': 0.03413515082190614, 'depth': 7, 'l2_leaf_reg': 19.362598557315625, 'border_count': 149, 'bagging_temperature': 0.7901463317663106, 'random_strength': 0.6894164823488307}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 00:12:05,573] Trial 64 finished with value: 0.7400057750414659 and parameters: {'iterations': 2040, 'learning_rate': 0.047674923475010365, 'depth': 7, 'l2_leaf_reg': 19.8803281335481, 'border_count': 32, 'bagging_temperature': 0.8993474210784334, 'random_strength': 2.005086409850517}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 00:15:02,391] Trial 65 finished with value: 0.7398787400286846 and parameters: {'iterations': 2008, 'learning_rate': 0.04954550629702812, 'depth': 7, 'l2_leaf_reg': 18.987244977305775, 'border_count': 38, 'bagging_temperature': 0.8971493811434, 'random_strength': 2.1819046631664927}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 00:17:16,558] Trial 66 finished with value: 0.7400512356413962 and parameters: {'iterations': 2245, 'learning_rate': 0.06527507795722143, 'depth': 7, 'l2_leaf_reg': 19.95420447586527, 'border_count': 190, 'bagging_temperature': 0.9323595418614492, 'random_strength': 0.9948348633057966}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 00:19:29,887] Trial 67 finished with value: 0.7398907188148768 and parameters: {'iterations': 2186, 'learning_rate': 0.06700159477408382, 'depth': 8, 'l2_leaf_reg': 19.743211250665038, 'border_count': 54, 'bagging_temperature': 0.9674738186924421, 'random_strength': 0.9109746501499141}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 00:22:16,216] Trial 68 finished with value: 0.74002347239768 and parameters: {'iterations': 2327, 'learning_rate': 0.06029603241826377, 'depth': 7, 'l2_leaf_reg': 19.977612006585264, 'border_count': 254, 'bagging_temperature': 0.9314340032303117, 'random_strength': 3.5979495530471244}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 00:24:50,234] Trial 69 finished with value: 0.7394008165705368 and parameters: {'iterations': 2379, 'learning_rate': 0.06104397398630378, 'depth': 8, 'l2_leaf_reg': 1.5430655259698245, 'border_count': 255, 'bagging_temperature': 0.9357722731922785, 'random_strength': 5.122625111676687}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 00:26:34,980] Trial 70 finished with value: 0.7397170647630779 and parameters: {'iterations': 2312, 'learning_rate': 0.07300493530466987, 'depth': 7, 'l2_leaf_reg': 18.420213224754587, 'border_count': 239, 'bagging_temperature': 0.9790883829296531, 'random_strength': 0.24516591391966813}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 00:29:27,043] Trial 71 finished with value: 0.7397922932547039 and parameters: {'iterations': 2578, 'learning_rate': 0.05511192809701501, 'depth': 7, 'l2_leaf_reg': 19.952062175301677, 'border_count': 222, 'bagging_temperature': 0.8967010876359137, 'random_strength': 3.6439380986697607}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 00:31:28,385] Trial 72 finished with value: 0.7400549496733977 and parameters: {'iterations': 2062, 'learning_rate': 0.08303290350827346, 'depth': 8, 'l2_leaf_reg': 19.212302776380596, 'border_count': 188, 'bagging_temperature': 0.8707133751796905, 'random_strength': 1.9090569604821321}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 00:33:48,272] Trial 73 finished with value: 0.7398602016608306 and parameters: {'iterations': 2174, 'learning_rate': 0.07154368497763669, 'depth': 8, 'l2_leaf_reg': 19.00410798350846, 'border_count': 181, 'bagging_temperature': 0.8204531996293322, 'random_strength': 2.477762510709514}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 00:36:01,608] Trial 74 finished with value: 0.7395496063621911 and parameters: {'iterations': 2542, 'learning_rate': 0.08395833819132639, 'depth': 9, 'l2_leaf_reg': 19.109315346892764, 'border_count': 189, 'bagging_temperature': 0.8648723920212504, 'random_strength': 6.026246224717847}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 00:38:37,889] Trial 75 finished with value: 0.7397231613751695 and parameters: {'iterations': 2069, 'learning_rate': 0.06231599015974416, 'depth': 8, 'l2_leaf_reg': 18.349628823797758, 'border_count': 206, 'bagging_temperature': 0.835703649732211, 'random_strength': 5.5180629872119775}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 00:40:39,145] Trial 76 finished with value: 0.7393431437449565 and parameters: {'iterations': 2273, 'learning_rate': 0.10145290801472187, 'depth': 8, 'l2_leaf_reg': 9.214499435652202, 'border_count': 229, 'bagging_temperature': 0.9236422712413667, 'random_strength': 6.690647213647245}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 00:42:44,148] Trial 77 finished with value: 0.7398193967997935 and parameters: {'iterations': 1869, 'learning_rate': 0.08403722186339543, 'depth': 7, 'l2_leaf_reg': 16.259011401143926, 'border_count': 172, 'bagging_temperature': 0.8600356608615045, 'random_strength': 4.340680209299542}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 00:46:07,995] Trial 78 finished with value: 0.7387936276069293 and parameters: {'iterations': 2402, 'learning_rate': 0.1175784749128137, 'depth': 10, 'l2_leaf_reg': 12.785402265812552, 'border_count': 184, 'bagging_temperature': 0.9580352910539922, 'random_strength': 2.9972094682484487}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 00:47:57,958] Trial 79 finished with value: 0.7397544449310616 and parameters: {'iterations': 1983, 'learning_rate': 0.09035641613144352, 'depth': 7, 'l2_leaf_reg': 19.370619253226224, 'border_count': 153, 'bagging_temperature': 0.9995017440414444, 'random_strength': 1.59987736210885}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 00:51:02,799] Trial 80 finished with value: 0.7397691894008924 and parameters: {'iterations': 2193, 'learning_rate': 0.04145453450437708, 'depth': 9, 'l2_leaf_reg': 17.061751652490464, 'border_count': 162, 'bagging_temperature': 0.8814168520334913, 'random_strength': 1.1273431632731665}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 00:54:05,708] Trial 81 finished with value: 0.7399542398632187 and parameters: {'iterations': 2034, 'learning_rate': 0.04850482763028657, 'depth': 7, 'l2_leaf_reg': 19.798312233162257, 'border_count': 207, 'bagging_temperature': 0.9203428557436268, 'random_strength': 2.024282248928861}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 00:56:13,192] Trial 82 finished with value: 0.7399980927284987 and parameters: {'iterations': 2073, 'learning_rate': 0.0787440686482554, 'depth': 7, 'l2_leaf_reg': 19.91897739727599, 'border_count': 70, 'bagging_temperature': 0.8082219277349367, 'random_strength': 1.8959390574098607}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 00:58:49,140] Trial 83 finished with value: 0.7398969852582183 and parameters: {'iterations': 2243, 'learning_rate': 0.05562428818507228, 'depth': 7, 'l2_leaf_reg': 18.54561992029089, 'border_count': 33, 'bagging_temperature': 0.9002587169305893, 'random_strength': 2.5590986536190106}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 01:05:47,136] Trial 84 finished with value: 0.7400295747387748 and parameters: {'iterations': 1867, 'learning_rate': 0.01683725977533453, 'depth': 8, 'l2_leaf_reg': 18.15472026738588, 'border_count': 140, 'bagging_temperature': 0.9517727774374518, 'random_strength': 1.360069966689275}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 01:12:39,495] Trial 85 finished with value: 0.7399945750545271 and parameters: {'iterations': 1870, 'learning_rate': 0.015820891073700008, 'depth': 8, 'l2_leaf_reg': 18.12527166571673, 'border_count': 139, 'bagging_temperature': 0.9580047421714247, 'random_strength': 0.73393569548047}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 01:16:05,754] Trial 86 finished with value: 0.7400122280226892 and parameters: {'iterations': 1942, 'learning_rate': 0.03635015427070036, 'depth': 8, 'l2_leaf_reg': 14.637005625386848, 'border_count': 170, 'bagging_temperature': 0.8415177344694752, 'random_strength': 1.4239961615797976}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 01:20:18,575] Trial 87 finished with value: 0.7400086347594284 and parameters: {'iterations': 1952, 'learning_rate': 0.02834941702011751, 'depth': 8, 'l2_leaf_reg': 17.404273733899004, 'border_count': 176, 'bagging_temperature': 0.13431689873634445, 'random_strength': 1.1259253838498966}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 01:24:09,412] Trial 88 finished with value: 0.7400447676788724 and parameters: {'iterations': 1736, 'learning_rate': 0.03568398301436874, 'depth': 8, 'l2_leaf_reg': 13.917534239531287, 'border_count': 188, 'bagging_temperature': 0.6839363632388227, 'random_strength': 1.7827763524720348}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 01:33:49,741] Trial 89 finished with value: 0.7398211058378128 and parameters: {'iterations': 1751, 'learning_rate': 0.012922381400222078, 'depth': 9, 'l2_leaf_reg': 11.537595983620182, 'border_count': 191, 'bagging_temperature': 0.570968580903031, 'random_strength': 2.892637340572768}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 01:40:49,810] Trial 90 finished with value: 0.7398586151633814 and parameters: {'iterations': 1699, 'learning_rate': 0.0180610654217256, 'depth': 9, 'l2_leaf_reg': 18.75869442909577, 'border_count': 199, 'bagging_temperature': 0.7038611145108815, 'random_strength': 2.3070791656093745}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 01:44:36,339] Trial 91 finished with value: 0.7400150498999978 and parameters: {'iterations': 1828, 'learning_rate': 0.03666933429737292, 'depth': 8, 'l2_leaf_reg': 14.660643875669004, 'border_count': 171, 'bagging_temperature': 0.6725264395869681, 'random_strength': 1.7497654417062676}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 01:49:07,407] Trial 92 finished with value: 0.7400384511815321 and parameters: {'iterations': 1814, 'learning_rate': 0.02776728619327236, 'depth': 8, 'l2_leaf_reg': 13.071787340776131, 'border_count': 185, 'bagging_temperature': 0.6861580120971333, 'random_strength': 1.748877568175579}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 01:59:05,426] Trial 93 finished with value: 0.7400008960691578 and parameters: {'iterations': 1780, 'learning_rate': 0.010065857292032389, 'depth': 8, 'l2_leaf_reg': 19.296835216451807, 'border_count': 184, 'bagging_temperature': 0.6243766602133223, 'random_strength': 0.8576253726239991}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 02:03:31,713] Trial 94 finished with value: 0.739903023227974 and parameters: {'iterations': 1695, 'learning_rate': 0.029681753550983063, 'depth': 8, 'l2_leaf_reg': 13.891958365162035, 'border_count': 127, 'bagging_temperature': 0.5431526267568852, 'random_strength': 1.7480520918807425}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 02:08:35,627] Trial 95 finished with value: 0.7400139119500243 and parameters: {'iterations': 1895, 'learning_rate': 0.023488131100847142, 'depth': 7, 'l2_leaf_reg': 13.09805140029288, 'border_count': 178, 'bagging_temperature': 0.7225217028490256, 'random_strength': 1.2587446622453984}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 02:14:26,743] Trial 96 finished with value: 0.7399276911727838 and parameters: {'iterations': 1614, 'learning_rate': 0.01938665032817497, 'depth': 8, 'l2_leaf_reg': 11.9892149691587, 'border_count': 205, 'bagging_temperature': 0.0398688109364832, 'random_strength': 1.4926510053911066}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 02:18:00,199] Trial 97 finished with value: 0.7395841682335501 and parameters: {'iterations': 1817, 'learning_rate': 0.028517098455151504, 'depth': 9, 'l2_leaf_reg': 15.774596334330152, 'border_count': 117, 'bagging_temperature': 0.6860370305088983, 'random_strength': 0.21925486136319094}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 02:20:41,588] Trial 98 finished with value: 0.7397903567375055 and parameters: {'iterations': 2327, 'learning_rate': 0.04178220863323864, 'depth': 7, 'l2_leaf_reg': 11.216177743333681, 'border_count': 215, 'bagging_temperature': 0.48439748960814955, 'random_strength': 0.5613897475526284}. Best is trial 33 with value: 0.7400806190663121.
# [I 2025-02-25 02:24:44,237] Trial 99 finished with value: 0.7398008542291059 and parameters: {'iterations': 2491, 'learning_rate': 0.03322874634817482, 'depth': 8, 'l2_leaf_reg': 9.900757581481688, 'border_count': 142, 'bagging_temperature': 0.7748496230115032, 'random_strength': 3.383807559069409}. Best is trial 33 with value: 0.7400806190663121.
# Best parameters: {'iterations': 1128, 'learning_rate': 0.01974308829097581, 'depth': 7, 'l2_leaf_reg': 14.254967637674017, 'border_count': 146, 'bagging_temperature': 0.6490942636012634, 'random_strength': 1.157639810266331}
